# %% [markdown]
# ![Pandas_logo.svg.png](attachment:Pandas_logo.svg.png)

# %% [markdown]
# # PANDAS
#      is a popular Python library used for data manipulation and analysis.
#
# * It features two main data structures:
#     * "series" object, representing a single column of data or observations related to a single variable,
#     * "data frame" object, which contains multiple columns of data.
#
# * Resources
#     * https://realpython.com/pandas-dataframe/

# %%
! pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Series
# A Pandas Series is a fundamental component of the Pandas library, representing a one-dimensional labeled array that can encompass diverse data types. Think of it as a single column in a spreadsheet, providing a structured way to organize and analyze data.
# <br/>
# ![9788b6e2.webp](attachment:9788b6e2.webp)

# %% [markdown]
# # Index
# In Pandas, think of an index like a row's address. It's a label or set of labels that helps us find and work with specific rows in our data, just like a primary key in a database table. This makes it easy to pick out the information we need. You can either tell Pandas what the index should be, or it can create one for you. The default is like having row numbers, starting from 0.

# %% [markdown]
# * Create Pandas Series from list or Numpy array

# %%
prices  = [10,20,46,14,25,98,63,64,79,58,26]

# %%
type(prices)

# %%
series_1 = pd.Series(prices)
series_1

# %%
type(series_1)

# %%
nd_array = np.array([10,20,35,64,8,4,96,45,54,6,8,7,1])
nd_array

# %%
type(nd_array)

# %%
series_2 = pd.Series(nd_array)
series_2

# %%
type(series_2)

# %%
# explore series's index by default it's a range start from 0
list(series_2.index)

# %%
# explore series's values
series_2.values

# %%
# define a series object as a view of the numpy array 
nd_array = np.array([1,2,3,5])
series_copy = pd.Series(nd_array , copy = False)

# %%
series_copy[0]

# %%
series_copy[0] = 99

# %%
series_copy

# %%
nd_array

# %%
#❖ Key/Value  as Series:
workdays={"day1":"sun","day2":"mon","day3":"tue"}
s = pd.Series(workdays)
print("Series: \n")
print(s)

# %%
s = pd.Series(workdays,index=["day1","day3"])
print("Series: \n")
print(s)

# %%
# define specific index for the pandas series
l = [44,5,66,2,2,33,65,4,5]
index = ["mohamed","ahmed","mahmoud","karim","majad","yasmine","farah","gad","youseef"]
series_3 = pd.Series(data= l , index = index )
series_3

# %%
series_3.index

# %%
series_3.values

# %%
# explore series shape (size,)
series_3.shape

# %%
# explore all information (data type , memory usage , index , non-null values count) about series
series_3.info()

# %%
# explore the occurance of each value in the series
series_3.value_counts()

# %%
# explore the summery statistics of the series
series_3.describe()

# %%
# explore unique values of the series
series_3.unique()

# %%
# statistics measures of the series 
series_3.count()

# %%
series_3.sum()

# %%
series_3.mean()

# %%
series_3.mode()

# %%
series_3.std()

# %%
series_3.var()

# %% [markdown]
# * Acees series elements using index

# %%
nd_array = np.array([10,20,35,64,8,4,96,45,54,6,8,7,1])
series_4 = pd.Series(nd_array)
series_4

# %%
series_4[0]

# %%
series_4[1]

# %%
series_4[0:4]

# %%
series_4[-1]

# %%
series_4.iloc[-2]

# %%
l = [44,5,66,2,2,33,65,4,5]
index = ["mohamed","ahmed","mahmoud","karim","majad","yasmine","farah","gad","youseef"]
series_5 = pd.Series(data= l , index = index )
series_5

# %%
series_5[1]

# %%
series_5[-1]

# %%
series_5['mahmoud']

# %%
series_5.loc['mahmoud']

# %% [markdown]
# * Arthematic Operations

# %%
series_6 = pd.Series(data=[1,2,3,4])
series_7 = pd.Series(data=[2,3,5,6])

# %%
series_6+series_7

# %%
series_6*series_7

# %%
series_6/series_7

# %%
series_6 = pd.Series(data=[1,2,3,4,5])
series_7 = pd.Series(data=[2,3,5,6])

# %%
series_6+series_7

# %%
series_6 = pd.Series(data=[1,2,3,4],index = ['mohamed','ahmed','karim','majad'])
series_7 = pd.Series(data=[2,3,5,6])

# %%
series_6+series_7

# %%
series_6 = pd.Series(data=[1,2,3,4],index = ['mohamed','ahmed','karim','majad'])
series_7 = pd.Series(data=[2,3,5,6],index = ['mohamed','ahmed','karim','majad'])

# %%
series_6+series_7

# %% [markdown]
# # DataFrame
# A Data Frame is a 2-dimensional labeled data structure with columns of potentially different types. It is similar to a spreadsheet or a SQL table.
# <br/>
# ![dataframe.webp](attachment:dataframe.webp)

# %%
# Create pandas DataFrame from dictionary of lists
data = {
    'Name': ['Emma', 'Oliver', 'Harry', 'Sophia'], 
    'Age': [29, 25, 33, 24],
    'Department': ['HR', 'Finance', 'Marketing', 'IT']}

df_1 = pd.DataFrame(data = data)
df_1

# %%
#Create pandas DataFrame from dictionary of numpy array.
np_array = np.array(
    [['Emma', 'Oliver', 'Harry', 'Sophia'],
     [29, 25, 33, 24],
     ['HR', 'Finance', 'Marketing', 'IT']])

data = {
    'Name': np_array[0],
    'Age': np_array[1],
    'Department': np_array[2]}

df_2 = pd.DataFrame(data = data )
df_2

# %%
#Create pandas DataFrame from numpy array.
np_array = np.array(
    [['Emma', 'Oliver', 'Harry', 'Sophia'],
     [29, 25, 33, 24],
     ['HR', 'Finance', 'Marketing', 'IT']])

# To transpose the numpy array
np_array = np_array.T

df_2 = pd.DataFrame(data = np_array , columns = ['Name','Age','Department'])
df_2

# %%
#Create pandas DataFrame from list of lists
data_rows = [
    ['Emma', 29, 'HR'],
    ['Oliver', 25, 'Finance'],
    ['Harry', 33, 'Marketing'],
    ['Sophia', 24, 'IT']]

df_3 = pd.DataFrame(data_rows, columns = ['Name', 'Age', 'Department'])
df_3

# %%
# Create pandas DataFrame from list of dictionaries
data_dict = [
    {'Name': 'Emma', 'Age': 29, 'Department': 'HR'},
    {'Name': 'Oliver', 'Age': 25, 'Department': 'Finance'},
    {'Name': 'Harry', 'Age': 33, 'Department': 'Marketing'},
    {'Name': 'Sophia', 'Age': 24, 'Department': 'IT'}]

df_4 = pd.DataFrame(data_dict)
df_4

# %%
# Create pandas Dataframe from dictionary of pandas Series

pd_series1 = pd.Series(['Emma', 'Oliver', 'Harry', 'Sophia'])
pd_series2 = pd.Series([29, 25, 33, 24])
pd_series3 = pd.Series(['HR', 'Finance', 'Marketing', 'IT'])

data_dict = {'Name': pd_series1, 'Age': pd_series2, 'Department':pd_series3}# Create the DataFrame
df_5 = pd.DataFrame(data_dict)
df_5

# %% [markdown]
# * Reading Files as DataFrame

# %% [markdown]
# ![Reading-and-Writing-Data-With-Pandas_Watermarked.webp](attachment:Reading-and-Writing-Data-With-Pandas_Watermarked.webp)

# %%
# Reading Csv Files 
# Arabic Encoding utf-8-sig

df_csv = pd.read_csv(r"C:\Users\moham\Downloads\Pandas\Titanic Dataset.csv",
                   encoding = 'utf-8' , sep = "," )

# %%
df_csv.head()

# %%
# Reading Excel Files 
df_excel = pd.read_excel(r'C:\Users\moham\Downloads\Pandas\Pandas Excel.xlsx',sheet_name = 0)

# %%
df_excel.head()

# %%
# Reading Json Files 
data_json = pd.read_json(r'C:\Users\moham\Downloads\Pandas\E-test.json')

# %%
data_json

# %% [markdown]
# * DataFrame elements access

# %%
data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Titanic Dataset.csv',index_col = 0 )

# %%
data.head()

# %%
# Selecting Multiple rows
data[:4]

# %%
data[0]

# %%
# Selecting Multiple columns
data[['Name','Survived']]

# %%
# loc   : select rows based on index and select columns based on columns's names
data.loc[1]

# %%
data.loc[1,'Name']

# %%
# Filtering the rows by condation inside loc function 
data.loc[data['Survived'] == 1,'Name']

# %%
# iloc   : select rows based on position and select columns based on columns's index
data.iloc[0]

# %%
data.iloc[0,2]

# %%
# Filtering the rows by condation not working with iloc
data.iloc[data['Survived'] == 1,2]

# %%
! pip install pyodbc

# %%
import pyodbc

# %%
server = 'MOHAMED-MAGDY'
database = 'Adventure Works'
username = 'MOHAMED-MAGDY\moham'
password = ''

connectionString = f'DRIVER={{SQL Server}};SERVER={server};DATABASE={database};'

# %%
conn = pyodbc.connect(connectionString)

# %%
SQL_QUERY = """
select DateKey , FullDateAlternateKey
from DimDate
"""

# %%
cursor = conn.cursor()
cursor.execute(SQL_QUERY)

# %%
records = cursor.fetchall()

# %%
type(records)
# Out:
# list

# %%
records[2]
# Out:
# (20050103, '2005-01-03')

# %%
type(records[0])
# Out:
# pyodbc.Row

# %%
cursor.description
# Out:
# (('DateKey', int, None, 10, 10, 0, False),
#  ('FullDateAlternateKey', str, None, 10, 10, 0, False))

# %%
pd.DataFrame([tuple(row) for row in records],columns = [i[0] for i in cursor.description])
# Out:
#        DateKey FullDateAlternateKey
# 0     20050101           2005-01-01
# 1     20050102           2005-01-02
# 2     20050103           2005-01-03
# 3     20050104           2005-01-04
# 4     20050105           2005-01-05
# ...        ...                  ...
# 3647  20141227           2014-12-27
# 3648  20141228           2014-12-28
# 3649  20141229           2014-12-29
# 3650  20141230           2014-12-30
# 3651  20141231           2014-12-31
#
# [3652 rows x 2 columns]

# %%
pd.DataFrame([tuple(row) for row in records], columns=[column[0] for column in cursor.description])
# Out:
#        DateKey FullDateAlternateKey
# 0     20050101           2005-01-01
# 1     20050102           2005-01-02
# 2     20050103           2005-01-03
# 3     20050104           2005-01-04
# 4     20050105           2005-01-05
# ...        ...                  ...
# 3647  20141227           2014-12-27
# 3648  20141228           2014-12-28
# 3649  20141229           2014-12-29
# 3650  20141230           2014-12-30
# 3651  20141231           2014-12-31
#
# [3652 rows x 2 columns]

# %% [markdown]
# * Filter and ordering

# %% [markdown]
# ![A-Guide-to-Pandas-Dataframes_Watermarked.7330c8fd51bb.avif](attachment:A-Guide-to-Pandas-Dataframes_Watermarked.7330c8fd51bb.avif)

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Sales.csv')

# %%
data
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       11/26/2013   26  November  2013            19     Youth (<25)
# 1       11/26/2015   26  November  2015            19     Youth (<25)
# 2        3/23/2014   23     March  2014            49  Adults (35-64)
# 3        3/23/2016   23     March  2016            49  Adults (35-64)
# 4        5/15/2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031   4/12/2016   12     April  2016            41  Adults (35-64)
# 113032    4/2/2014    2     April  2014            18     Youth (<25)
# 113033    4/2/2016    2     April  2016            18     Youth (<25)
# 113034    3/4/2014    4     March  2014            37  Adults (35-64)
# 113035    3/4/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
data[data['Year'] == 2014].head()
# Out:
#          Date  Day     Month  Year  Customer_Age             Age_Group  \
# 2   3/23/2014   23     March  2014            49        Adults (35-64)
# 4   5/15/2014   15       May  2014            47        Adults (35-64)
# 6   5/22/2014   22       May  2014            47        Adults (35-64)
# 8   2/22/2014   22  February  2014            35        Adults (35-64)
# 18  1/22/2014   22   January  2014            29  Young Adults (25-34)
#
#    Customer_Gender    Country             State Product_Category  ...  \
# 2                M  Australia   New South Wales      Accessories  ...
# 4                F  Australia   New South Wales      Accessories  ...
# 6                F  Australia          Victoria      Accessories  ...
# 8                M  Australia          Victoria      Accessories  ...
# 18               M     Canada  British Columbia      Accessories  ...
#
#                 Product Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data[(data['Year'] == 2014) & (data['Month'] == 'May')]
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 4       5/15/2014   15   May  2014            47        Adults (35-64)
# 6       5/22/2014   22   May  2014            47        Adults (35-64)
# 20      5/17/2014   17   May  2014            29  Young Adults (25-34)
# 32      5/23/2014   23   May  2014            47        Adults (35-64)
# 72      5/30/2014   30   May  2014            38        Adults (35-64)
# ...           ...  ...   ...   ...           ...                   ...
# 112946  5/23/2014   23   May  2014            22           Youth (<25)
# 112972  5/26/2014   26   May  2014            60        Adults (35-64)
# 112984   5/5/2014    5   May  2014            25  Young Adults (25-34)
# 113002  5/23/2014   23   May  2014            20           Youth (<25)
# 113004   5/3/2014    3   May  2014            21           Youth (<25)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
data[(data['Year'] == 2014) | (data['Month'] == 'May')]
# Out:
#              Date  Day  Month  Year  Customer_Age             Age_Group  \
# 2       3/23/2014   23  March  2014            49        Adults (35-64)
# 4       5/15/2014   15    May  2014            47        Adults (35-64)
# 5       5/15/2016   15    May  2016            47        Adults (35-64)
# 6       5/22/2014   22    May  2014            47        Adults (35-64)
# 7       5/22/2016   22    May  2016            47        Adults (35-64)
# ...           ...  ...    ...   ...           ...                   ...
# 113022  3/20/2014   20  March  2014            34  Young Adults (25-34)
# 113024   4/3/2014    3  April  2014            34  Young Adults (25-34)
# 113030  4/12/2014   12  April  2014            41        Adults (35-64)
# 113032   4/2/2014    2  April  2014            18           Youth (<25)
# 113034   3/4/2014    4  March  2014            37        Adults (35-64)
#
#        Customer_Gender         Country            State Product_Category  ...  \
# ...

# %%
data[~(data['Year'] == 2014) & (data['Month'] == 'May')]
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 5       5/15/2016   15   May  2016            47        Adults (35-64)
# 7       5/22/2016   22   May  2016            47        Adults (35-64)
# 21      5/17/2016   17   May  2016            29  Young Adults (25-34)
# 33      5/23/2016   23   May  2016            47        Adults (35-64)
# 73      5/30/2016   30   May  2016            38        Adults (35-64)
# ...           ...  ...   ...   ...           ...                   ...
# 112947  5/23/2016   23   May  2016            22           Youth (<25)
# 112973  5/26/2016   26   May  2016            60        Adults (35-64)
# 112985   5/5/2016    5   May  2016            25  Young Adults (25-34)
# 113003  5/23/2016   23   May  2016            20           Youth (<25)
# 113005   5/3/2016    3   May  2016            21           Youth (<25)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
specific_country = ['Australia','Canada']

data[data['Country'].isin(specific_country)]
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0       11/26/2013   26  November  2013            19           Youth (<25)
# 1       11/26/2015   26  November  2015            19           Youth (<25)
# 2        3/23/2014   23     March  2014            49        Adults (35-64)
# 3        3/23/2016   23     March  2016            49        Adults (35-64)
# 4        5/15/2014   15       May  2014            47        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 112999    4/6/2016    6     April  2016            58        Adults (35-64)
# 113008   1/18/2014   18   January  2014            32  Young Adults (25-34)
# 113009   1/18/2016   18   January  2016            32  Young Adults (25-34)
# 113032    4/2/2014    2     April  2014            18           Youth (<25)
# 113033    4/2/2016    2     April  2016            18           Youth (<25)
#
# ...

# %%
data[data['Country'].str.contains('United')]
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 22       3/27/2014   27     March  2014            51        Adults (35-64)
# 23       3/27/2016   27     March  2016            51        Adults (35-64)
# 34       7/19/2013   19      July  2013            32  Young Adults (25-34)
# 35       7/19/2015   19      July  2015            32  Young Adults (25-34)
# 38       7/13/2013   13      July  2013            43        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 113025    4/3/2016    3     April  2016            34  Young Adults (25-34)
# 113028  12/28/2013   28  December  2013            41        Adults (35-64)
# 113029  12/28/2015   28  December  2015            41        Adults (35-64)
# 113030   4/12/2014   12     April  2014            41        Adults (35-64)
# 113031   4/12/2016   12     April  2016            41        Adults (35-64)
#
# ...

# %%
data[data['Age_Group'].str.contains('Adults')]
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 2        3/23/2014   23     March  2014            49  Adults (35-64)
# 3        3/23/2016   23     March  2016            49  Adults (35-64)
# 4        5/15/2014   15       May  2014            47  Adults (35-64)
# 5        5/15/2016   15       May  2016            47  Adults (35-64)
# 6        5/22/2014   22       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113029  12/28/2015   28  December  2015            41  Adults (35-64)
# 113030   4/12/2014   12     April  2014            41  Adults (35-64)
# 113031   4/12/2016   12     April  2016            41  Adults (35-64)
# 113034    3/4/2014    4     March  2014            37  Adults (35-64)
# 113035    3/4/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country            State Product_Category  ...  \
# ...

# %%
data.filter(items=['Age_Group','Year'],axis=1)
# Out:
#              Age_Group  Year
# 0          Youth (<25)  2013
# 1          Youth (<25)  2015
# 2       Adults (35-64)  2014
# 3       Adults (35-64)  2016
# 4       Adults (35-64)  2014
# ...                ...   ...
# 113031  Adults (35-64)  2016
# 113032     Youth (<25)  2014
# 113033     Youth (<25)  2016
# 113034  Adults (35-64)  2014
# 113035  Adults (35-64)  2016
#
# [113036 rows x 2 columns]

# %%
data_temp = data.set_index('Country')

# %%
data_temp
# Out:
#                       Date  Day     Month  Year  Customer_Age       Age_Group  \
# Country
# Canada          11/26/2013   26  November  2013            19     Youth (<25)
# Canada          11/26/2015   26  November  2015            19     Youth (<25)
# Australia        3/23/2014   23     March  2014            49  Adults (35-64)
# Australia        3/23/2016   23     March  2016            49  Adults (35-64)
# Australia        5/15/2014   15       May  2014            47  Adults (35-64)
# ...                    ...  ...       ...   ...           ...             ...
# United Kingdom   4/12/2016   12     April  2016            41  Adults (35-64)
# Australia         4/2/2014    2     April  2014            18     Youth (<25)
# Australia         4/2/2016    2     April  2016            18     Youth (<25)
# France            3/4/2014    4     March  2014            37  Adults (35-64)
# France            3/4/2016    4     March  2016            37  Adults (35-64)
#
# ...

# %%
data_temp.filter(items=['France','Australia'],axis=0)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10560\2641498891.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   data_temp.filter(items=['France','Australia'],axis=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 data_temp.filter(items=['France','Australia'],axis=0)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5131, in NDFrame.filter(self, items, like, regex, axis)
#    5129 if items is not None:
#    5130     name = self._get_axis_name(axis)
# -> 5131     return self.reindex(**{name: [r for r in items if r in labels]})
#    5132 elif like:
#    5134     def f(x) -> bool_t:
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
# ...

# %%
data_temp.reset_index()
# Out:
#                Country        Date  Day     Month  Year  Customer_Age  \
# 0               Canada  11/26/2013   26  November  2013            19
# 1               Canada  11/26/2015   26  November  2015            19
# 2            Australia   3/23/2014   23     March  2014            49
# 3            Australia   3/23/2016   23     March  2016            49
# 4            Australia   5/15/2014   15       May  2014            47
# ...                ...         ...  ...       ...   ...           ...
# 113031  United Kingdom   4/12/2016   12     April  2016            41
# 113032       Australia    4/2/2014    2     April  2014            18
# 113033       Australia    4/2/2016    2     April  2016            18
# 113034          France    3/4/2014    4     March  2014            37
# 113035          France    3/4/2016    4     March  2016            37
#
#              Age_Group Customer_Gender             State Product_Category  \
# ...

# %%
data_temp=data_temp.set_index('Order ID')

# %%
data_temp
# Out:
#                 Date  Day     Month  Year  Customer_Age       Age_Group  \
# Order ID
# 1005268   11/26/2013   26  November  2013            19     Youth (<25)
# 1005269   11/26/2015   26  November  2015            19     Youth (<25)
# 1005270    3/23/2014   23     March  2014            49  Adults (35-64)
# 1005271    3/23/2016   23     March  2016            49  Adults (35-64)
# 1005272    5/15/2014   15       May  2014            47  Adults (35-64)
# ...              ...  ...       ...   ...           ...             ...
# 1118299    4/12/2016   12     April  2016            41  Adults (35-64)
# 1118300     4/2/2014    2     April  2014            18     Youth (<25)
# 1118301     4/2/2016    2     April  2016            18     Youth (<25)
# 1118302     3/4/2014    4     March  2014            37  Adults (35-64)
# 1118303     3/4/2016    4     March  2016            37  Adults (35-64)
#
#          Customer_Gender             State Product_Category Sub_Category  \
# Order ID
# ...

# %%
data_temp.filter(items=[1118301,1118300],axis=0)
# Out:
#               Date  Day  Month  Year  Customer_Age    Age_Group  \
# Order ID
# 1118301   4/2/2016    2  April  2016            18  Youth (<25)
# 1118300   4/2/2014    2  April  2014            18  Youth (<25)
#
#          Customer_Gender       State Product_Category Sub_Category  \
# Order ID
# 1118301                M  Queensland         Clothing        Vests
# 1118300                M  Queensland         Clothing        Vests
#
#                   Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# Order ID
# 1118301   Classic Vest, M              22         24          64     655
# 1118300   Classic Vest, M              22         24          64     655
#
#           Cost  Revenue Shipment Status  Unnamed: 20
# Order ID
# 1118301    528     1183            Sent          NaN
# 1118300    528     1183            Sent          NaN

# %%
data_temp.filter(like ='1118301',axis=0)
# Out:
#               Date  Day  Month  Year  Customer_Age    Age_Group  \
# Order ID
# 1118301   4/2/2016    2  April  2016            18  Youth (<25)
#
#          Customer_Gender       State Product_Category Sub_Category  \
# Order ID
# 1118301                M  Queensland         Clothing        Vests
#
#                   Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# Order ID
# 1118301   Classic Vest, M              22         24          64     655
#
#           Cost  Revenue Shipment Status  Unnamed: 20
# Order ID
# 1118301    528     1183            Sent          NaN

# %% [markdown]
# * Ordering

# %% [markdown]
# ![Pandas-Sort_Watermarked.webp](attachment:Pandas-Sort_Watermarked.webp)

# %% [markdown]
# * Ordering index

# %%
data_temp = data_temp.reset_index()

# %%
data_temp.set_index(['State','Order ID'],inplace = True)
data_temp

# %%
data_temp.sort_index(level = ['State','Order ID'],ascending = [True , False])
# Out:
#                         Date  Day     Month  Year  Customer_Age  \
# State   Order ID
# Alabama 1080995    7/13/2016   13      July  2016            40
#         1080994    7/13/2014   13      July  2014            40
#         1080993   11/15/2015   15  November  2015            40
#         1080992   11/15/2013   15  November  2013            40
# Alberta 1115617    6/30/2016   30      June  2016            39
# ...                      ...  ...       ...   ...           ...
# Yveline 1005754     3/1/2014    1     March  2014            30
#         1005719    8/25/2015   25    August  2015            22
#         1005718    8/25/2013   25    August  2013            22
#         1005713    5/22/2016   22       May  2016            44
#         1005712    5/22/2014   22       May  2014            44
#
#                              Age_Group Customer_Gender Product_Category  \
# State   Order ID
# Alabama 1080995         Adults (35-64)               F      Accessories
# ...

# %% [markdown]
# * Ordering values

# %%
data.sort_values(by='Order_Quantity',ascending = True)
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 56517   12/23/2011   23  December  2011            35        Adults (35-64)
# 68566    1/24/2014   24   January  2014            36        Adults (35-64)
# 68567    1/24/2016   24   January  2016            36        Adults (35-64)
# 68568    5/10/2014   10       May  2014            36        Adults (35-64)
# 68570    5/14/2014   14       May  2014            36        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 103136   2/17/2016   17  February  2016            29  Young Adults (25-34)
# 77852    7/24/2016   24      July  2016            37        Adults (35-64)
# 15258    5/23/2016   23       May  2016            22           Youth (<25)
# 23127     4/4/2016    4     April  2016            35        Adults (35-64)
# 37725    4/15/2016   15     April  2016            49        Adults (35-64)
#
# ...

# %%
data.sort_values(by=['Order_Quantity','Revenue'] , ascending = [True,False])[['Order_Quantity','Revenue']]
# Out:
#         Order_Quantity  Revenue
# 58584                1     3542
# 58585                1     3542
# 58978                1     3542
# 58979                1     3542
# 58980                1     3542
# ...                ...      ...
# 100524              32       51
# 81992               32       50
# 81997               32       50
# 98305               32       50
# 107995              32       50
#
# [113036 rows x 2 columns]

# %% [markdown]
# * Group by and Aggregating

# %%
data
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       11/26/2013   26  November  2013            19     Youth (<25)
# 1       11/26/2015   26  November  2015            19     Youth (<25)
# 2        3/23/2014   23     March  2014            49  Adults (35-64)
# 3        3/23/2016   23     March  2016            49  Adults (35-64)
# 4        5/15/2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031   4/12/2016   12     April  2016            41  Adults (35-64)
# 113032    4/2/2014    2     April  2014            18     Youth (<25)
# 113033    4/2/2016    2     April  2016            18     Youth (<25)
# 113034    3/4/2014    4     March  2014            37  Adults (35-64)
# 113035    3/4/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
data.groupby(by=['Country'])['Revenue'].mean()
# Out:
# Country
# Australia         889.959016
# Canada            559.721964
# France            766.764139
# Germany           809.028293
# United Kingdom    781.659031
# United States     713.552696
# Name: Revenue, dtype: float64

# %%
data.groupby(by=['Country'])['Revenue'].max()
# Out:
# Country
# Australia         58074
# Canada            14312
# France            13740
# Germany           14169
# United Kingdom    13740
# United States     14026
# Name: Revenue, dtype: int64

# %%
data.groupby(by=['Country'])['Revenue'].count()
# Out:
# Country
# Australia         23936
# Canada            14178
# France            10998
# Germany           11098
# United Kingdom    13620
# United States     39206
# Name: Revenue, dtype: int64

# %%
data.groupby(by = ['Country']).agg({'Revenue':['max','mean','median']})
# Out:
#                Revenue
#                    max        mean median
# Country
# Australia        58074  889.959016  300.5
# Canada           14312  559.721964  144.0
# France           13740  766.764139  249.0
# Germany          14169  809.028293  312.0
# United Kingdom   13740  781.659031  253.0
# United States    14026  713.552696  196.0

# %%
data.groupby(by = ['Country']).describe()
# Out:
#                     Day                                                   \
#                   count       mean       std  min  25%   50%   75%   max
# Country
# Australia       23936.0  15.720254  8.809928  1.0  8.0  16.0  23.0  31.0
# Canada          14178.0  15.501340  8.820438  1.0  8.0  15.0  23.0  31.0
# France          10998.0  15.783779  8.719278  1.0  8.0  16.0  23.0  31.0
# Germany         11098.0  15.575419  8.900618  1.0  8.0  15.0  23.0  31.0
# United Kingdom  13620.0  15.681645  8.676021  1.0  8.0  16.0  23.0  31.0
# United States   39206.0  15.678876  8.769588  1.0  8.0  16.0  23.0  31.0
#
#                    Year               ...    Order ID            Unnamed: 20  \
#                   count         mean  ...         75%        max       count
# Country                               ...
# Australia       23936.0  2014.303016  ...  1087885.25  1118301.0         0.0
# Canada          14178.0  2014.453096  ...  1087730.75  1118223.0         0.0
# ...

# %% [markdown]
# # Merge , Join and Concatenate

# %% [markdown]
# ![Merging-Joining-and-Concatenating-in-Pandas_Watermarked_1.webp](attachment:Merging-Joining-and-Concatenating-in-Pandas_Watermarked_1.webp)

# %% [markdown]
# * Merge
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

# %%
sales_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_1.csv')

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12988 entries, 0 to 12987
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CurrencyKey       12988 non-null  int64
#  1   CustomerKey       12988 non-null  int64
#  2   OrderDateKey      12988 non-null  int64
#  3   OrderQuantity     12988 non-null  int64
#  4   ProductKey        12988 non-null  int64
#  5   SalesAmount       12988 non-null  object
#  6   TaxAmt            12988 non-null  object
#  7   TotalProductCost  12988 non-null  object
#  8   UnitPrice         12988 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 913.3+ KB

# %%
sales_data.head()
# Out:
#    CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0            6        11000      20110119              1         344
# 1            6        11000      20130118              1         353
# 2            6        11000      20130118              1         485
# 3            6        11000      20130503              1         214
# 4            6        11000      20130503              1         488
#
#   SalesAmount     TaxAmt TotalProductCost UnitPrice
# 0    $3399.99  $271.9992       $1912.1544  $3399.99
# 1    $2319.99  $185.5992       $1265.6195  $2319.99
# 2      $21.98    $1.7584          $8.2205    $21.98
# 3      $34.99    $2.7992         $13.0863    $34.99
# 4      $53.99    $4.3192         $41.5723    $53.99

# %%
products_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\Dimproduct.csv')

# %%
products_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ProductKey          606 non-null    int64
#  1   EnglishProductName  606 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 9.6+ KB

# %%
products_data.head()
# Out:
#    ProductKey      EnglishProductName
# 0           1         Adjustable Race
# 1         486  All-Purpose Bike Stand
# 2         223            AWC Logo Cap
# 3         224            AWC Logo Cap
# 4         225            AWC Logo Cap

# %%
sales_data.merge

# %%
sales_data.merge(products_data , how = 'inner' , left_on = 'ProductKey',right_on = 'ProductKey').head()
# Out:
#    CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0            6        11000      20110119              1         344
# 1            6        11011      20101230              1         344
# 2            6        11030      20110205              1         344
# 3            6        11054      20110203              1         344
# 4            6        11072      20110331              1         344
#
#   SalesAmount     TaxAmt TotalProductCost UnitPrice       EnglishProductName
# 0    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38
# 1    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38
# 2    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38
# 3    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38
# 4    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38

# %%
sales_data.merge(sales_data , how = 'inner' , 
                 left_on = 'ProductKey',right_on = 'ProductKey',
                 suffixes =('_left','_right')).head()
# Out:
#    CurrencyKey_left  CustomerKey_left  OrderDateKey_left  OrderQuantity_left  \
# 0                 6             11000           20110119                   1
# 1                 6             11000           20110119                   1
# 2                 6             11000           20110119                   1
# 3                 6             11000           20110119                   1
# 4                 6             11000           20110119                   1
#
#    ProductKey SalesAmount_left TaxAmt_left TotalProductCost_left  \
# 0         344         $3399.99   $271.9992            $1912.1544
# 1         344         $3399.99   $271.9992            $1912.1544
# 2         344         $3399.99   $271.9992            $1912.1544
# 3         344         $3399.99   $271.9992            $1912.1544
# 4         344         $3399.99   $271.9992            $1912.1544
#
#   UnitPrice_left  CurrencyKey_right  CustomerKey_right  OrderDateKey_right  \
# ...

# %%
currency_rates = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\FactCurrencyrate.csv')

# %%
currency_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14264 entries, 0 to 14263
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateKey      14264 non-null  int64
#  1   Date         14264 non-null  object
#  2   CurrencyKey  14264 non-null  int64
#  3   AverageRate  14264 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 445.9+ KB

# %%
currency_rates.head()
# Out:
#     DateKey                 Date  CurrencyKey  AverageRate
# 0  20101229  2010-12-29 00:00:00            3     1.000000
# 1  20101229  2010-12-29 00:00:00            6     0.645536
# 2  20101229  2010-12-29 00:00:00           14     0.001576
# 3  20101229  2010-12-29 00:00:00           16     0.516022
# 4  20101229  2010-12-29 00:00:00           19     0.683013

# %%
sales_data.merge(right = currency_rates , how = 'inner' ,
                 left_on = ['OrderDateKey','CurrencyKey'] , right_on = ['DateKey','CurrencyKey'])
# Out:
#        CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0                6        11000      20110119              1         344
# 1                6        11029      20110119              1         347
# 2                6        16484      20110119              1         314
# 3                6        16623      20110119              1         312
# 4                6        11000      20130118              1         353
# ...            ...          ...           ...            ...         ...
# 12983            6        27493      20121202              1         337
# 12984            6        27498      20121202              1         325
# 12985            6        27488      20121130              1         329
# 12986            6        27489      20121130              1         325
# 12987            6        27490      20121130              1         343
#
#       SalesAmount     TaxAmt TotalProductCost UnitPrice   DateKey  \
# ...

# %%
sales_data.merge(right = currency_rates , how = 'inner' ,
                 left_on = ['OrderDateKey','CurrencyKey'] , right_on = ['DateKey','CurrencyKey'] ,
                 indicator=True).head()
# Out:
#    CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0            6        11000      20110119              1         344
# 1            6        11029      20110119              1         347
# 2            6        16484      20110119              1         314
# 3            6        16623      20110119              1         312
# 4            6        11000      20130118              1         353
#
#   SalesAmount     TaxAmt TotalProductCost UnitPrice   DateKey  \
# 0    $3399.99  $271.9992       $1912.1544  $3399.99  20110119
# 1    $3399.99  $271.9992       $1912.1544  $3399.99  20110119
# 2    $3578.27  $286.2616       $2171.2942  $3578.27  20110119
# 3    $3578.27  $286.2616       $2171.2942  $3578.27  20110119
# 4    $2319.99  $185.5992       $1265.6195  $2319.99  20130118
#
#                   Date  AverageRate _merge
# 0  2011-01-19 00:00:00     0.632911   both
# 1  2011-01-19 00:00:00     0.632911   both
# 2  2011-01-19 00:00:00     0.632911   both
# ...

# %%
df1 = pd.DataFrame({"col1": [0, 1], "col_left": ["a", "b"]})

df2 = pd.DataFrame({"col1": [1, 2, 2], "col_right": [2, 2, 2]})

pd.merge(df1, df2, on="col1", how="outer", indicator=True)
# Out:
#    col1 col_left  col_right      _merge
# 0     0        a        NaN   left_only
# 1     1        b        2.0        both
# 2     2      NaN        2.0  right_only
# 3     2      NaN        2.0  right_only

# %% [markdown]
# * Concat
# ![image.png](attachment:image.png)

# %%
df_sales_1 = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_1.csv')

# %%
df_sales_1.shape
# Out:
# (12988, 9)

# %%
df_sales_2 = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_2.csv')

# %%
df_sales_2.shape
# Out:
# (7131, 9)

# %%
df_sales_3 = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_3.csv')

# %%
df_sales_3.shape
# Out:
# (76, 9)

# %%
df_sales_4 = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_4.csv')

# %%
df_sales_4.shape
# Out:
# (59, 9)

# %%
sales_data = pd.concat([df_sales_1,df_sales_2,df_sales_3,df_sales_4])

# %%
sales_data.shape
# Out:
# (20254, 9)

# %%
sales_data.tail(50)
# Out:
#     CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 9            39        12131      20110221              1         311
# 10           39        12132      20110130              1         310
# 11           39        12211      20110307              1         313
# 12           39        12212      20110327              1         313
# 13           39        12217      20110323              1         311
# 14           39        12219      20110324              1         312
# 15           39        12220      20110309              1         314
# 16           39        12221      20110302              1         311
# 17           39        12254      20110316              1         313
# 18           39        12255      20110321              1         313
# 19           39        12256      20110330              1         311
# 20           39        12261      20110422              1         312
# ...

# %%
sales_data.tail(50)
# Out:
#        CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 20204           39        12131      20110221              1         311
# 20205           39        12132      20110130              1         310
# 20206           39        12211      20110307              1         313
# 20207           39        12212      20110327              1         313
# 20208           39        12217      20110323              1         311
# 20209           39        12219      20110324              1         312
# 20210           39        12220      20110309              1         314
# 20211           39        12221      20110302              1         311
# 20212           39        12254      20110316              1         313
# 20213           39        12255      20110321              1         313
# 20214           39        12256      20110330              1         311
# 20215           39        12261      20110422              1         312
# ...

# %%
# axis 0 concat in the row dimension
# axis 1 concat based on the index 
df1 = pd.DataFrame(
    {"A": ["A0", "A1", "A2", "A3"],"B": ["B0", "B1", "B2", "B3"],
     "C": ["C0", "C1", "C2", "C3"],"D": ["D0", "D1", "D2", "D3"]},index=[0, 1, 2, 3])

df2 = pd.DataFrame(
    { "B": ["B2", "B3", "B6", "B7"],"D": ["D2", "D3", "D6", "D7"],"F": ["F2", "F3", "F6", "F7"],}
    ,index=[2, 3, 6, 7])

# %%
result = pd.concat([df1, df2], axis=0)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1, df2], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df2], axis=1,join = 'inner')
result
# Out:
#     0   1   2   3   4   5   6
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# * Join
# ![merging_join_outer.png](attachment:merging_join_outer.png)

# %%
left = pd.DataFrame({"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"])

right = pd.DataFrame({"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"])

# %%
result = left.join(right , how = 'inner')
result
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
result = left.join(right , how = 'outer')
result
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
result = pd.merge(left, right, left_index=True, right_index=True, how="outer")
result
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# # Data Exploration using Pandas

# %% [markdown]
# ![Intro-to-Exploratory-Data-Analysis-With-Pandas_Watermarked.webp](attachment:Intro-to-Exploratory-Data-Analysis-With-Pandas_Watermarked.webp)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\factsales_1.csv')

# %%
currency_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\Dimcurrency.csv')

# %%
products_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\Dimproduct.csv')

# %%
date_data = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\Dimdate.csv')

# %%
currency_rate = pd.read_csv(r'C:\Users\moham\Downloads\Pandas\Adventureworks_sales_data\FactCurrencyrate.csv')

# %%
sales_data.head(2)
# Out:
#    CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0            6        11000      20110119              1         344
# 1            6        11000      20130118              1         353
#
#   SalesAmount     TaxAmt TotalProductCost UnitPrice
# 0    $3399.99  $271.9992       $1912.1544  $3399.99
# 1    $2319.99  $185.5992       $1265.6195  $2319.99

# %%
currency_data.head(2)
# Out:
#    CurrencyKey    CurrencyName
# 0            1         Afghani
# 1            2  Algerian Dinar

# %%
products_data.head(2)
# Out:
#    ProductKey      EnglishProductName
# 0           1         Adjustable Race
# 1         486  All-Purpose Bike Stand

# %%
date_data.head(2)
# Out:
#     DateKey FullDateAlternateKey
# 0  20050101  2005-01-01 00:00:00
# 1  20050102  2005-01-02 00:00:00

# %%
currency_rate.head(2)
# Out:
#     DateKey                 Date  CurrencyKey  AverageRate
# 0  20101229  2010-12-29 00:00:00            3     1.000000
# 1  20101229  2010-12-29 00:00:00            6     0.645536

# %%
full_data = pd.merge(left = sales_data , right = products_data , on = 'ProductKey' , how = 'inner')

# %%
full_data = pd.merge(left = full_data , right =currency_data , on = 'CurrencyKey' , how = 'inner' )

# %%
full_data = pd.merge(left = full_data , right = date_data , left_on = 'OrderDateKey' ,right_on='DateKey' , how = 'inner')

# %%
full_data = pd.merge(left = full_data , right = currency_rate , how = 'inner',
                     left_on = ['OrderDateKey','CurrencyKey'] , right_on = ['DateKey','CurrencyKey'] )

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12988 entries, 0 to 12987
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CurrencyKey           12988 non-null  int64
#  1   CustomerKey           12988 non-null  int64
#  2   OrderDateKey          12988 non-null  int64
#  3   OrderQuantity         12988 non-null  int64
#  4   ProductKey            12988 non-null  int64
#  5   SalesAmount           12988 non-null  object
#  6   TaxAmt                12988 non-null  object
#  7   TotalProductCost      12988 non-null  object
#  8   UnitPrice             12988 non-null  object
#  9   EnglishProductName    12988 non-null  object
#  10  CurrencyName          12988 non-null  object
#  11  DateKey_x             12988 non-null  int64
#  12  FullDateAlternateKey  12988 non-null  object
#  13  DateKey_y             12988 non-null  int64
#  14  Date                  12988 non-null  object
# ...

# %%
full_data['FullDateAlternateKey'] = pd.to_datetime(full_data['FullDateAlternateKey'])

# %%
full_data.head(2)
# Out:
#    CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  ProductKey  \
# 0            6        11000      20110119              1         344
# 1            6        11029      20110119              1         347
#
#   SalesAmount     TaxAmt TotalProductCost UnitPrice       EnglishProductName  \
# 0    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 38
# 1    $3399.99  $271.9992       $1912.1544  $3399.99  Mountain-100 Silver, 48
#
#         CurrencyName  DateKey_x FullDateAlternateKey  DateKey_y  \
# 0  Australian Dollar   20110119           2011-01-19   20110119
# 1  Australian Dollar   20110119           2011-01-19   20110119
#
#                   Date  AverageRate
# 0  2011-01-19 00:00:00     0.632911
# 1  2011-01-19 00:00:00     0.632911

# %%
full_data = full_data.set_index('FullDateAlternateKey')

# %%
full_data.head()
# Out:
#                       CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  \
# FullDateAlternateKey
# 2011-01-19                      6        11000      20110119              1
# 2011-01-19                      6        11029      20110119              1
# 2011-01-19                      6        16623      20110119              1
# 2011-01-19                      6        16484      20110119              1
# 2010-12-30                      6        11011      20101230              1
#
#                       ProductKey SalesAmount     TaxAmt TotalProductCost  \
# FullDateAlternateKey
# 2011-01-19                   344    $3399.99  $271.9992       $1912.1544
# 2011-01-19                   347    $3399.99  $271.9992       $1912.1544
# 2011-01-19                   312    $3578.27  $286.2616       $2171.2942
# 2011-01-19                   314    $3578.27  $286.2616       $2171.2942
# 2010-12-30                   344    $3399.99  $271.9992       $1912.1544
#
# ...

# %%
full_data.dtypes
# Out:
# CurrencyKey             int64
# CustomerKey             int64
# OrderDateKey            int64
# OrderQuantity           int64
# ProductKey              int64
# SalesAmount            object
# TaxAmt                 object
# TotalProductCost       object
# UnitPrice              object
# EnglishProductName     object
# CurrencyName           object
# DateKey_x               int64
# DateKey_y               int64
# Date                   object
# AverageRate           float64
# dtype: object

# %%
strip_columns = ['SalesAmount','TaxAmt','TotalProductCost','AverageRate']

full_data[strip_columns] = full_data[strip_columns].astype(str)

full_data[strip_columns] = full_data[strip_columns].apply(lambda x: x.str.strip('$'))

# %%
convert_dict = {'SalesAmount': float,
                'TaxAmt': float , 
                'TotalProductCost':float , 
                'AverageRate':float
                }
full_data = full_data.astype(convert_dict)

# %%
full_data['Proft_General_Currency'] = (full_data['SalesAmount'] - full_data['TaxAmt'] 
                                       - full_data['TotalProductCost'] ) * full_data['AverageRate']

# %%
full_data.head(2)
# Out:
#                       CurrencyKey  CustomerKey  OrderDateKey  OrderQuantity  \
# FullDateAlternateKey
# 2011-01-19                      6        11000      20110119              1
# 2011-01-19                      6        11029      20110119              1
#
#                       ProductKey  SalesAmount    TaxAmt  TotalProductCost  \
# FullDateAlternateKey
# 2011-01-19                   344      3399.99  271.9992         1912.1544
# 2011-01-19                   347      3399.99  271.9992         1912.1544
#
#                      UnitPrice       EnglishProductName       CurrencyName  \
# FullDateAlternateKey
# 2011-01-19            $3399.99  Mountain-100 Silver, 38  Australian Dollar
# 2011-01-19            $3399.99  Mountain-100 Silver, 48  Australian Dollar
#
#                       DateKey_x  DateKey_y                 Date  AverageRate  \
# FullDateAlternateKey
# 2011-01-19             20110119   20110119  2011-01-19 00:00:00     0.632911
# ...

# %%
full_data['SalesAmount_General_currency'] = full_data['SalesAmount'] *  full_data['AverageRate']

# %%
full_data['TotalProductCost_General_currency'] = full_data['TotalProductCost'] *  full_data['AverageRate']

# %%
full_data.groupby(by=['FullDateAlternateKey'])[['SalesAmount_General_currency','TotalProductCost_General_currency','Proft_General_Currency']].sum().plot(figsize  = (15,10) , kind = 'line',subplots = True)
# Out:
# array([<AxesSubplot:xlabel='FullDateAlternateKey'>,
#        <AxesSubplot:xlabel='FullDateAlternateKey'>,
#        <AxesSubplot:xlabel='FullDateAlternateKey'>], dtype=object)

# %% [markdown]
# # Data Visualization using Pandas
# <br>

# %% [markdown]
# ![How-to-Plot-With-Pandas_Watermarked.webp](attachment:How-to-Plot-With-Pandas_Watermarked.webp)

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=('col_1', 'col_2', 'col_3', 'col_4'))

# %%
df
# Out:
#        col_1     col_2     col_3     col_4
# 0   0.656721  0.621315  0.421033  0.415234
# 1   0.275319  0.813100  0.857189  0.302651
# 2   0.555266  0.338734  0.456849  0.948493
# 3   0.779145  0.068524  0.341676  0.448859
# 4   0.218260  0.784574  0.692484  0.337891
# 5   0.368241  0.498757  0.346282  0.786916
# 6   0.454395  0.988242  0.309530  0.702040
# 7   0.009387  0.046814  0.690226  0.861392
# 8   0.508593  0.021864  0.387509  0.159343
# 9   0.457799  0.902815  0.999557  0.962670
# 10  0.512627  0.309746  0.194638  0.006013
# 11  0.916589  0.124483  0.656136  0.089481
# 12  0.697580  0.871340  0.269042  0.130585
# 13  0.195602  0.096256  0.964313  0.428863
# 14  0.337732  0.205296  0.543391  0.268298
# 15  0.783250  0.105179  0.388227  0.427755
# 16  0.778090  0.436842  0.415051  0.563677
# 17  0.040262  0.174192  0.987260  0.880365
# 18  0.053758  0.094069  0.723857  0.597341
# 19  0.796876  0.179670  0.761599  0.841503
# 20  0.744673  0.387968  0.242971  0.707454
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot

# %%
df.plot(kind = 'line',figsize  = (15,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'line',figsize  = (15,10) , subplots = True,sharex = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(kind = 'line',figsize  = (15,10) , xlabel = "Time" , ylabel = "Values" , title = 'Values change over Time')
# Out:
# <AxesSubplot:title={'center':'Values change over Time'}, xlabel='Time', ylabel='Values'>

# %%
df.plot(kind="bar", y='col_1',figsize  = (20,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar", x='col_1',y='col_2',figsize  = (20,5))
# Out:
# <AxesSubplot:xlabel='col_1'>

# %%
df.plot(kind="bar",figsize  = (20,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar",figsize  = (20,5),stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True,figsize  = (20,5))
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(y = 'col_1',figsize  = (20,5) , bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(figsize  = (20,10) , bins = 10 )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(figsize  = (20,10) , bins = 10 , subplots = True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
df.plot.box(figsize  = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.box(figsize  = (20,10),vert=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(figsize  = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.area(figsize  = (20,10) , stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(figsize  = (20,10),subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot.scatter(x='col_1', y='col_3',figsize  = (20,10),color = 'red' ,  marker="*",s=100)
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_3'>

# %%
df.plot.scatter(x='col_1', y='col_3',figsize  = (20,10), c='col_4' ,  marker="*",s=100)
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_3'>

# %%
df_csv = pd.read_csv(r"C:\Users\moham\Downloads\Pandas\Titanic Dataset.csv",
                   encoding = 'utf-8' , sep = "," )

# %%
df_csv.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df_csv['Pclass'].value_

# %%
df_csv.groupby(by = 'Survived')['PassengerId'].count().plot.pie(figsize  = (7,7),legend = True)
# Out:
# <AxesSubplot:ylabel='PassengerId'>
