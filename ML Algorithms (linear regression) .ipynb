# %% [markdown]
# # Machine Learning Algorithms

# %% [markdown]
# ### • Data Preparation

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [3,21,22,34,54,34,55,67,89,99]
x = np.array(x)
y = [1,10,14,34,44,36,22,67,79,90]
y =np.array(y)

plt.scatter(x,y)

# %%
# the basic linear regression model is wx+b.
def model(a,b,x):
    return a*x + b

# %%
#the most commonly used loss function of kinear regression.
def loss_function(a,b,x,y):
    num = len(x)
    prediction = model(a,b,x)
    loss = (0.5/num) * (np.square(prediction-y)*x).sum()
    return loss

# %%
#the optimization function mainly uses partial derivatives of the loss function on a and b.
def optimize(a,b,x,y):
    num = len(x)
    prediction = model(a,b,x)
    # update the values of a and b by finding the partial derivatives of the loss function on a and b.
    da = (1.0/num) * ((prediction - y)*x).sum()
    db = (1.0/num) * ((prediction - y).sum())
    a = a - lr*da                  
    b = b - lr*db
    return a , b

# %%
#iterated function, return a and b.
def iterate(a,b,x,y,times):
    for i in range(times):
        a,b = optimize(a,b,x,y)
    return a,b

# %%
#initialize parameters and display.
a=np.random.rand(1)
print(a)
b=np.random.rand(1)
print(b)
lr = 1e-4
# Out:
# [0.72247184]
# [0.46312563]

# %%
#for the first iteration, the parameter values , losses.

#iterate(1)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.76258639] [0.4635959] 3752.534372380515

# %%
#iterate(2)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.79010353] [0.46387438] 3149.7783731909985

# %%
#iterate(3)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.8089795] [0.4640213] 2841.3547812403776

# %%
#iterate(4)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.8219281] [0.46407798] 2679.2128250705077

# %%
#iterate(5)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.83081082] [0.46407275] 2591.244154491448

# %%
#iterate(6)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.83690457] [0.46402507] 2541.8416265587775

# %%
#iterate(7)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.84395362] [0.46385148] 2495.8044406618337

# %%
#iterate(8)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.84592185] [0.463741] 2485.0777870364277

# %%
#iterate(9)
a,b = iterate(a,b,x,y,1)
prediction = model(a,b,x)
loss = loss_function(a,b,x,y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.84727263] [0.46362112] 2478.253460947451
